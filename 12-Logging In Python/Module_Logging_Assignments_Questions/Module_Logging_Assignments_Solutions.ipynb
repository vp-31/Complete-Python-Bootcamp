# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.

# %%
import logging

def basic_logger():
    logging.basicConfig(filename='app.log', level=logging.DEBUG)
    logging.debug('This is a debug message')
    logging.info('This is an info message')
    logging.warning('This is a warning message')
    logging.error('This is an error message')
    logging.critical('This is a critical message')

# Test the function
basic_logger()

# %% [markdown]
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.

# %%
import logging
def logger_with_handlers():
    logger = logging.getLogger('my_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('app.log')
    console_handler = logging.StreamHandler()
    
    file_handler.setLevel(logging.DEBUG)
    console_handler.setLevel(logging.DEBUG)
    
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_handlers()
# Out:
# 2024-08-18 09:24:58,156 - my_logger - DEBUG - This is a debug message
# 2024-08-18 09:24:58,157 - my_logger - INFO - This is an info message
# 2024-08-18 09:24:58,159 - my_logger - WARNING - This is a warning message
# 2024-08-18 09:24:58,161 - my_logger - ERROR - This is an error message
# 2024-08-18 09:24:58,163 - my_logger - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different logging levels for the file and console handlers.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.

# %%
import logging

def logger_with_custom_format():
    logger = logging.getLogger('custom_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('custom_app.log')
    console_handler = logging.StreamHandler()
    
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_custom_format()
# Out:
# 2024-08-18 09:30:02,866 - DEBUG - This is a debug message
# 2024-08-18 09:30:02,868 - INFO - This is an info message
# 2024-08-18 09:30:02,870 - WARNING - This is a warning message
# 2024-08-18 09:30:02,872 - ERROR - This is an error message
# 2024-08-18 09:30:02,874 - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different formats for the file and console handlers.

# %%
import logging
def logger_with_different_formats():
    logger = logging.getLogger('multi_format_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('multi_format_app.log')
    console_handler = logging.StreamHandler()
    
    file_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(file_formatter)
    console_handler.setFormatter(console_formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_different_formats()
# Out:
# 2024-08-18 09:42:20,030 - DEBUG - This is a debug message
# 2024-08-18 09:42:20,033 - INFO - This is an info message
# 2024-08-18 09:42:20,036 - WARNING - This is a warning message
# 2024-08-18 09:42:20,038 - ERROR - This is an error message
# 2024-08-18 09:42:20,040 - CRITICAL - This is a critical message

# %% [markdown]
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.

# %%
import logging

from logging.handlers import RotatingFileHandler

def logger_with_rotating_file_handler():
    logger = logging.getLogger('rotating_logger')
    logger.setLevel(logging.DEBUG)
    
    rotating_handler = RotatingFileHandler('rotating_app.log', maxBytes=2000, backupCount=2)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    rotating_handler.setFormatter(formatter)
    
    logger.addHandler(rotating_handler)
    
    for i in range(100):
        logger.debug('This is debug message number {}'.format(i))

# Test the function
logger_with_rotating_file_handler()

# %% [markdown]
# 2. Modify the function to keep a specified number of backup log files.

# %%
# The modification is already included in the above function with backupCount=5.

# %% [markdown]
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.

# %%
def log_exception():
    logger = logging.getLogger('exception_logger')
    logger.setLevel(logging.ERROR)
    
    file_handler = logging.FileHandler('exception_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    try:
        1 / 0
    except Exception as e:
        logger.exception("An exception occurred")

# Test the function
log_exception()

# %% [markdown]
# 2. Modify the function to log the stack trace at the ERROR level.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.

# %%
def logger_with_context():
    logger = logging.getLogger('context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    def test_func():
        logger.debug('This is a debug message')
        logger.info('This is an info message')
        logger.warning('This is a warning message')
        logger.error('This is an error message')
        logger.critical('This is a critical message')
    
    test_func()

# Test the function
logger_with_context()

# %% [markdown]
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).

# %%
import logging
def logger_with_additional_context(user_id, session_id):
    logger = logging.getLogger('additional_context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('additional_context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d - UserID: %(user_id)s - SessionID: %(session_id)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    extra = {'user_id': user_id, 'session_id': session_id}
    
    def test_func():
        logger.debug('This is a debug message', extra=extra)
        logger.info('This is an info message', extra=extra)
        logger.warning('This is a warning message', extra=extra)
        logger.error('This is an error message', extra=extra)
        logger.critical('This is a critical message', extra=extra)
    
    test_func()

# Test the function
logger_with_additional_context('user123', 'session456')

# %% [markdown]
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.

# %%
import logging
import logging.config

def configure_logging_with_dict():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            },
            'detailed': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'dict_config_app.log',
                'formatter': 'detailed',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)
    logger = logging.getLogger('')
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
configure_logging_with_dict()
# Out:
# 2024-08-18 12:22:32,256 - root - DEBUG - This is a debug message
# 2024-08-18 12:22:32,257 - root - INFO - This is an info message
# 2024-08-18 12:22:32,260 - root - WARNING - This is a warning message
# 2024-08-18 12:22:32,261 - root - ERROR - This is an error message
# 2024-08-18 12:22:32,263 - root - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the dictionary to include different logging levels and formats for each handler.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.

# %% [markdown]
# #### File: `main.py`

# %%
import logging
from module_a import module_a_function
from module_b import module_b_function

def setup_logging():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'multi_module_app.log',
                'formatter': 'default',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)

# Main script
if __name__ == '__main__':
    setup_logging()
    logger = logging.getLogger(__name__)
    logger.info('Main module started')
    module_a_function()
    module_b_function()
    logger.info('Main module finished')
# Out:
# 2024-08-18 12:26:27,785 - __main__ - INFO - Main module started
# 2024-08-18 12:26:27,787 - module_a - INFO - Module A function started
# 2024-08-18 12:26:27,789 - module_a - DEBUG - This is a debug message from Module A
# 2024-08-18 12:26:27,790 - module_a - INFO - Module A function finished
# 2024-08-18 12:26:27,792 - module_b - INFO - Module B function started
# 2024-08-18 12:26:27,793 - module_b - DEBUG - This is a debug message from Module B
# 2024-08-18 12:26:27,795 - module_b - INFO - Module B function finished
# 2024-08-18 12:26:27,798 - __main__ - INFO - Main module finished

# %% [markdown]
# #### File: `module_a.py`

# %%
import logging

def module_a_function():
    logger = logging.getLogger(__name__)
    logger.info('Module A function started')
    logger.debug('This is a debug message from Module A')
    logger.info('Module A function finished')

# %% [markdown]
# #### File: `module_b.py`

# %%
import logging

def module_b_function():
    logger = logging.getLogger(__name__)
    logger.info('Module B function started')
    logger.debug('This is a debug message from Module B')
    logger.info('Module B function finished')

# %% [markdown]
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.

# %%
# The modification is already included in the above scripts. Each module's logger messages propagate to the root logger.

# %% [markdown]
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).

# %%
import logging
import time
from logging.handlers import RotatingFileHandler

def benchmark_logging_performance():
    logger = logging.getLogger('performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler
    file_handler = logging.FileHandler('performance_file.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # Console handler
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.DEBUG)
    logger.addHandler(console_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Console handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler
- performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,569 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,572 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,577 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,578 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,580 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,584 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,586 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,590 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,591 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,595 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,596 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,598 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,601 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,602 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,607 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,608 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,611 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,614 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,617 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,620 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,624 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,626 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,627 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,630 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,632 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,636 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,641 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,643 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,646 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,647 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,652 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,653 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,656 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,660 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,662 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,665 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,669 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,670 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,674 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,678 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,682 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,684 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,686 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,692 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,694 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,697 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,699 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,702 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,704 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,706 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,707 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,708 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,710 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,712 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,713 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,715 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,719 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,723 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,725 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,726 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,728 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,729 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,730 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,731 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,734 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,735 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,737 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,738 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,740 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,741 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,749 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,755 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,760 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,765 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,771 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,775 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,777 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,782 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,785 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,790 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,793 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,797 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,800 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,804 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,805 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,808 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,814 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,819 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,821 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,823 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,829 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,832 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,834 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,836 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,837 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,838 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,840 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,841 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,843 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,844 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,845 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,846 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,848 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,850 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,852 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,854 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,855 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,856 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,859 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,860 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,862 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,863 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,865 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,872 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,874 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,875 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,877 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,878 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,880 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,881 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,883 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,885 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,886 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,888 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,889 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,891 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,892 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,893 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,895 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,896 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,897 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,898 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,899 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,902 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,903 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,904 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,905 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,906 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,908 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,908 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,910 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,911 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,913 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,914 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,915 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,916 - performance_logger - DEBUG - This is a debug message
# 2024-08-18 12:49:57,917 - performance_logger - DEBUG - This is a debug message
# Rotating file handler logging time: 21.0890212059021 seconds

# %% [markdown]
# 2. Modify the script to compare the performance of logging with and without message formatting.

# %%
def benchmark_logging_formatting_performance():
    logger = logging.getLogger('formatting_performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler without formatting
    file_handler = logging.FileHandler('performance_no_format.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time without formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # File handler with formatting
    file_handler = logging.FileHandler('performance_with_format.log')
    file_handler.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time with formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

# Test the function
benchmark_logging_formatting_performance()

# %% [markdown]
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.

# %% [markdown]
# #### File: `logging.conf`

# %%
[loggers]
keys=root

[handlers]
keys=fileHandler,consoleHandler

[formatters]
keys=defaultFormatter

[logger_root]
level=DEBUG
handlers=fileHandler,consoleHandler

[handler_fileHandler]
class=FileHandler
level=DEBUG
formatter=defaultFormatter
args=('advanced_logging_app.log', 'a')

[handler_consoleHandler]
class=StreamHandler
level=DEBUG
formatter=defaultFormatter
args=(sys.stdout,)

[formatter_defaultFormatter]
format=%(asctime)s - %(name)s - %(levelname)s - %(message)s
# Out:
#   Cell In[2], line 15
#     class=FileHandler
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### File: `main.py`

# %%
import logging
import logging.config

def setup_logging_from_file():
    logging.config.fileConfig('logging.conf')
    logger = logging.getLogger(__name__)
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
setup_logging_from_file()
# Out:
# 2024-08-18 12:57:24,885 - __main__ - DEBUG - This is a debug message
# 2024-08-18 12:57:24,887 - __main__ - INFO - This is an info message
# 2024-08-18 12:57:24,889 - __main__ - WARNING - This is a warning message
# 2024-08-18 12:57:24,890 - __main__ - ERROR - This is an error message
# 2024-08-18 12:57:24,892 - __main__ - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
# The modification is already included in the above configuration file.
